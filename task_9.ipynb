# %% [markdown]
# ## Bivariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('online food delivery.csv')

# %%
df
# Out:
#      Unnamed: 0  age  gender marital_status occupation   monthly_income  \
# 0             0   20  Female         Single    Student        No Income
# 1             1   24  Female         Single    Student   Below Rs.10000
# 2             2   22    Male         Single    Student   Below Rs.10000
# 3             3   22  Female         Single    Student        No Income
# 4             4   22    Male         Single    Student   Below Rs.10000
# ..          ...  ...     ...            ...        ...              ...
# 280         355   21    Male         Single    Student        No Income
# 281         363   31    Male        Married   Employee  More than 50000
# 282         369   30    Male        Married   Employee  More than 50000
# 283         374   21    Male         Single    Student        No Income
# 284         386   23    Male         Single    Student   Below Rs.10000
#
#     educational_qualifications  family_size customer_type  latitude  \
# ...

# %%
sns.scatterplot(data=df,x='family_size',y='age')
plt.title("Age vs Family_size")
plt.ylabel('Age')
plt.xlabel('Family_size')
plt.show()

# %%
corr = df[['age', 'family_size']].corr()

sns.heatmap(corr, annot=True)

plt.show()

# %% [markdown]
# ## Categorical vs Numerical

# %%
sns.barplot(data=df, x='gender', y='family_size')

plt.title("Average Family Size by Gender")
plt.show()

# %%
sns.boxplot(data=df, x='gender', y='occupation')

plt.title("Occupation by Gender")
plt.show()

# %%
sns.barplot(
    data=df,
    x='educational_qualifications',
    y='family_size'
)

plt.xticks(rotation=45)
plt.title("Average Family Size by Education Qualification")
plt.show()

# %%
sns.boxplot(data=df, x='feedback', y='age')

plt.title("Age Distribution by Feedback")
plt.xlabel("Feedback")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# ## Other

# %%
sns.barplot(
    data=df,
    x='occupation',
    y='family_size'
)

plt.xticks(rotation=45)
plt.title("Average Family Size by Occupation")
plt.show()

# %%
pd.crosstab(df['gender'], df['occupation'])
# Out:
# occupation  Employee  House wife  Self Employeed  Student
# gender
# Female            41           9              12       59
# Male              53           0              26       85
